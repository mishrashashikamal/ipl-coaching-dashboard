# %%
import google.generativeai as genai

genai.configure(api_key="AQ.Ab8RN6Kx6OpKMDhNce4DGclPnAzVAwpPhBLTZ0l8jwfjr2X7cA")

model = genai.GenerativeModel("gemini-2.5-flash")

response = model.generate_content("Say hello")

print(response.text)
# Out:
# Hello!

# %%
# ============================================
# AI COACHING REPORT GENERATOR
# ============================================

import google.generativeai as genai

genai.configure(api_key="AQ.Ab8RN6Kx6OpKMDhNce4DGclPnAzVAwpPhBLTZ0l8jwfjr2X7cA")
model = genai.GenerativeModel("gemini-2.5-flash")

player = "MS Dhoni"

# All Dhoni's stats we analyzed
prompt = f"""
You are an expert IPL cricket coach. Based on the following 
data analysis of {player}, generate a professional coaching report.

PLAYER STATS:
- Total Balls Faced: 3947
- Total Runs: 5243
- Strike Rate: 132.84
- Dot Ball %: 36.05%

PHASE-WISE STRIKE RATE:
- Powerplay (0-5): 75.64
- Middle (6-14): 99.01
- Death (15-19): 168.13

DISMISSAL PATTERNS:
- Caught: 92 (62%)
- Run Out: 25 (17%)
- Bowled: 20 (13%)
- Pace dismissals: 79.87%
- Spin dismissals: 20.13%

TOP BOWLERS WHO DISMISSED HIM:
- PP Ojha (Left arm spin): 7 times
- Z Khan (Left arm pace): 7 times
- JJ Bumrah (Right arm pace): 4 times

BEST VENUES:
- Mohali: SR 179.49
- Chinnaswamy: SR 177.01

WORST VENUES:
- Arun Jaitley Stadium Delhi: SR 83.05
- Motera Ahmedabad: SR 88.14

DEATH OVERS PRESSURE:
- Death overs SR: 196.97
- Avg runs per match: 20.02
- Total sixes in death overs: 136

Please provide:
1. Overall player assessment (3-4 lines)
2. Key strengths (3 points)
3. Key weaknesses (3 points)
4. Specific practice drills (4-5 drills)
5. Match strategy recommendations (3 points)
"""

print("Generating AI coaching report... 🤖")
response = model.generate_content(prompt)
print(response.text)
# Out:
# Generating AI coaching report... 🤖
# As an expert IPL cricket coach, here is a detailed professional coaching report for MS Dhoni based on the provided data analysis:
#
# ---
#
# ### **MS Dhoni: Player Coaching Report**
#
# **1. Overall Player Assessment**
# MS Dhoni is an elite, high-impact finisher renowned for his exceptional composure and power-hitting prowess in the death overs. He strategically builds his innings through the middle phase, setting himself up to unleash a devastating assault when it matters most. His ability to consistently deliver under pressure makes him a match-winner, despite specific challenges early in his innings and on certain venue types.
#
# **2. Key Strengths**
#
# *   **Elite Death Overs Finisher:** Dhoni's strike rate of **196.97** in death overs, averaging **20.02 runs per match**, and hitting **136 sixes**, unequivocally establishes him as one of the most destructive and reliable finishers in IPL history. His ability to accelerate rapidly and close out games is unparalleled.
# *   **Strategic Middle Overs Accumulator:** With a strike rate of **99.01** in the middle overs (6-14), he effectively rotates strike and accumulates runs, building a solid platform without taking undue risks, which is crucial for setting up his late-innings heroics.
# *   **High-Impact on Batting-Friendly Pitches:** Dhoni thrives on surfaces conducive to strokeplay, evidenced by his phenomenal strike rates at Mohali (**179.49**) and Chinnaswamy (**177.01**). This makes him an invaluable asset in high-scoring encounters.
#
# **3. Key Weaknesses**
#
# *   **Powerplay and Early Innings Strike Rate:** A significant drop in strike rate to **75.64** in the Powerplay (0-5) indicates a struggle for quick scoring if he's forced to bat early. This could lead to pressure on the team if exposed during the initial overs.
# *   **Vulnerability to Specific Bowler Types (Left-Arm Pace & Spin):** Frequent dismissals by **Z Khan (Left-arm pace - 7 times)** and **PP Ojha (Left-arm spin - 7 times)** highlight a specific challenge against these angles and variations, despite a lower overall spin dismissal percentage. Pace overall accounts for nearly 80% of his dismissals.
# *   **Struggles on Slower/Challenging Surfaces:** His significantly lower strike rates at Arun Jaitley Stadium Delhi (**83.05**) and Motera Ahmedabad (**88.14**) suggest difficulty adapting to pitches that are slower, offer low bounce, or assist spinners more, impacting his fluency.
#
# **4. Specific Practice Drills**
#
# *   **Early Innings Gap Hitting & Rotation Drill:** Batting in simulated Powerplay conditions against new ball bowlers (including left-arm pace), focusing on playing conventional cricketing shots, finding gaps, and aggressively rotating the strike to convert dot balls into singles, rather than solely relying on boundaries.
# *   **Left-Arm Bowler Specific Net Sessions:** Dedicated nets against left-arm pacers (focus on countering the angle, inswing, and wide yorkers) and left-arm spinners (practicing sweeps, advancing down the pitch, and playing against the spin to pierce fields). Utilize bowling machines for consistency in lines and lengths.
# *   **Slow Pitch Adaptability Drill:** Practice sessions on prepared slow or low-bouncing wickets, focusing on precise timing, late bat-speed, using the depth of the crease, and manipulating fields for singles and twos against both pace and spin without over-hitting.
# *   **"Set Finisher" Scenario Training:** Intensive death overs simulation where Dhoni starts with a pre-defined run rate requirement from a certain over, facing various bowler types (including pace variations and yorkers) under high-pressure scenarios, ensuring he can consistently execute his boundary-hitting game.
#
# **5. Match Strategy Recommendations**
#
# *   **Optimal Entry Point & Role Definition:** Strategically deploy Dhoni to bat predominantly after the Powerplay (ideally from over 7-8 onwards) to allow him to settle and leverage his middle-overs accumulation before unleashing his finishing prowess. Avoid exposing him to new-ball pressure unless absolutely critical.
# *   **Targeted Counter-Strategy vs. Left-Arm Bowlers:** When facing teams with prominent left-arm pacers or left-arm spinners, formulate a specific plan. This might involve shielding him temporarily, having another batter take more risks against that bowler, or encouraging pre-meditated aggression to disrupt the bowler's rhythm if the matchup is unfavorable.
# *   **Tactical Batting on Difficult Pitches:** On venues like Delhi or Ahmedabad, where his strike rate drops significantly, encourage a more measured approach. Prioritize rotating strike, finding gaps, and running hard between wickets, rather than attempting power-hitting, which may lead to dismissals on unresponsive surfaces.

# %%
# ============================================
# SAVE THE COACHING REPORT
# ============================================

# Save report to a file
with open('dhoni_coaching_report.txt', 'w', encoding='utf-8') as f:
    f.write(f"IPL COACHING REPORT — {player}\n")
    f.write("="*50 + "\n\n")
    f.write(response.text)

print("✅ Report saved to dhoni_coaching_report.txt!")
# Out:
# ✅ Report saved to dhoni_coaching_report.txt!

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\shashi kamal mishra\anaconda3\lib\site-packages (1.1.0)
