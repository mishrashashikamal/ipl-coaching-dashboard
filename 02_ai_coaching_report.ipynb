# %%
import google.generativeai as genai

from dotenv import load_dotenv
import os

load_dotenv()  # reads .env file
API_KEY = os.getenv("GEMINI_API_KEY")  # gets key safely

model = genai.GenerativeModel("gemini-2.5-flash")

response = model.generate_content("Say hello")

print(response.text)
# Out:
# Hello!

# %%
# ============================================
# AI COACHING REPORT GENERATOR
# ============================================

import google.generativeai as genai


from dotenv import load_dotenv
import os

load_dotenv()  # reads .env file
API_KEY = os.getenv("GEMINI_API_KEY")  # gets key safely
model = genai.GenerativeModel("gemini-2.5-flash")

player = "MS Dhoni"

# All Dhoni's stats we analyzed
prompt = f"""
You are an expert IPL cricket coach. Based on the following 
data analysis of {player}, generate a professional coaching report.

PLAYER STATS:
- Total Balls Faced: 3947
- Total Runs: 5243
- Strike Rate: 132.84
- Dot Ball %: 36.05%

PHASE-WISE STRIKE RATE:
- Powerplay (0-5): 75.64
- Middle (6-14): 99.01
- Death (15-19): 168.13

DISMISSAL PATTERNS:
- Caught: 92 (62%)
- Run Out: 25 (17%)
- Bowled: 20 (13%)
- Pace dismissals: 79.87%
- Spin dismissals: 20.13%

TOP BOWLERS WHO DISMISSED HIM:
- PP Ojha (Left arm spin): 7 times
- Z Khan (Left arm pace): 7 times
- JJ Bumrah (Right arm pace): 4 times

BEST VENUES:
- Mohali: SR 179.49
- Chinnaswamy: SR 177.01

WORST VENUES:
- Arun Jaitley Stadium Delhi: SR 83.05
- Motera Ahmedabad: SR 88.14

DEATH OVERS PRESSURE:
- Death overs SR: 196.97
- Avg runs per match: 20.02
- Total sixes in death overs: 136

Please provide:
1. Overall player assessment (3-4 lines)
2. Key strengths (3 points)
3. Key weaknesses (3 points)
4. Specific practice drills (4-5 drills)
5. Match strategy recommendations (3 points)
"""

print("Generating AI coaching report... 🤖")
response = model.generate_content(prompt)
print(response.text)
# Out:
# Generating AI coaching report... 🤖
# ## Professional Coaching Report: MS Dhoni
#
# **1. Overall Player Assessment:**
# MS Dhoni remains an iconic figure in IPL cricket, showcasing an unparalleled ability to dictate terms and finish innings in the death overs. While his overall strike rate is respectable, his game displays a clear dichotomy, transitioning from a cautious middle-overs accumulator to an explosive, match-winning finisher. His experience and composure under pressure continue to be invaluable assets to any team.
#
# **2. Key Strengths:**
#
# *   **Elite Death Overs Finisher:** Dhoni's staggering strike rate of 196.97 in death overs, coupled with 136 sixes, unequivocally establishes him as one of the most destructive and reliable closers in IPL history. He thrives under immense pressure, consistently delivering high-impact performances at the crucial stage.
# *   **Power Hitting on Favourable Tracks:** His exceptional strike rates at venues like Mohali (179.49) and Chinnaswamy (177.01) demonstrate his ability to exploit good batting surfaces and short boundaries, maximizing his power game when conditions are conducive.
# *   **Durability and Game Experience:** With over 5200 runs from 3947 balls faced, Dhoni brings immense experience, strategic acumen, and a proven track record of performing consistently over a prolonged IPL career, offering invaluable leadership and stability.
#
# **3. Key Weaknesses:**
#
# *   **Middle Overs Acceleration & Dot Ball Pressure:** A strike rate of 99.01 in the middle overs (6-14) and a 36.05% overall dot ball percentage indicate a struggle to maintain scoring momentum during this phase. This can put undue pressure on subsequent batsmen or leave too much for the death overs.
# *   **Vulnerability to Left-Arm Angles (Pace & Spin):** Specific data shows recurring challenges against left-arm bowlers, with 7 dismissals each to PP Ojha (left-arm spin) and Z Khan (left-arm pace). This suggests a potential area of exposure against the incoming angle and natural variation.
# *   **Struggles on Slower/Difficult Pitches:** His significantly lower strike rates at venues like Arun Jaitley Stadium (83.05) and Motera (88.14) highlight a difficulty in adapting his aggressive game to slower, lower, or potentially turning tracks where timing can be harder to achieve.
#
# **4. Specific Practice Drills:**
#
# *   **"Middle Overs Intent" Simulation:** Conduct net sessions focusing on rotating strike and finding boundaries against spin and medium pace in the middle overs (balls 60-120 of an innings). Emphasize converting singles into twos, playing sweeps/reverse sweeps, and using the crease to find gaps, aiming to reduce the dot ball percentage by 5-10%.
# *   **"Left-Arm Bowler Challenge" Drills:** Dedicated sessions facing left-arm pacers (focus on playing straight, adjusting to inswing/angle across) and left-arm spinners (practicing different releases like arm ball, turn, and slider; working on clearing the front leg or playing late for line). Utilize bowling machines to replicate specific angles and variations.
# *   **"Slow Pitch Power & Placement" Drills:** Practice sessions on worn or damp pitches (or artificially slow surfaces) that replicate difficult batting conditions. Focus on generating power from the core, using wrist work for placement, and hitting down the ground rather than relying on brute force to overcome the lack of pace.
# *   **"Aggressive Running & Conversion" Drills:** Implement high-intensity running drills between wickets, emphasizing quick decision-making for singles and aggressively converting ones into twos. Include drills with a partner to improve communication and reduce the risk of run-outs.
# *   **"First 10 Ball Impact" Drill (Scenario-Based):** If coming in during the middle overs, simulate scenarios where he needs to hit a boundary or take 2 quick singles within his first 5-10 balls to establish momentum and break the rhythm of the bowler, particularly against quality spinners.
#
# **5. Match Strategy Recommendations:**
#
# *   **Optimized Entry Point:** Strategically deploy MS Dhoni from overs 10-12 onwards, allowing him sufficient time to assess the pitch and match situation without the immediate pressure of early acceleration. This maximises his death-overs impact by giving him a platform.
# *   **Targeted Spin Negotiation:** When left-arm spin is operating, encourage calculated aggression or strategic rotation of strike, especially early in his innings against that specific bowling type. Consider using a designated hitter at the other end to absorb pressure or target specific over/match-ups for boundary hitting.
# *   **Pitch-Specific Game Plan:** On slower or turning surfaces (e.g., Delhi, Chennai), advise a more measured approach initially. Prioritize quick singles and doubles to keep the scoreboard ticking, and target specific bowlers or phases for boundary hitting, rather than trying to force the pace against the inherent nature of the pitch.

# %%
# ============================================
# SAVE THE COACHING REPORT
# ============================================

# Save report to a file
with open('dhoni_coaching_report.txt', 'w', encoding='utf-8') as f:
    f.write(f"IPL COACHING REPORT — {player}\n")
    f.write("="*50 + "\n\n")
    f.write(response.text)

print("✅ Report saved to dhoni_coaching_report.txt!")
# Out:
# ✅ Report saved to dhoni_coaching_report.txt!

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\users\shashi kamal mishra\anaconda3\lib\site-packages (1.1.0)
